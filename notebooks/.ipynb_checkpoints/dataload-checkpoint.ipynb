# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
sys.path.insert(0, '../')

# %%
from src.dataloader import build_data_loader

loader = build_data_loader(
    data_dir='/home/data/ShapeNet/ShapeNetV1processed/',
    split_name='train_eval', #or 'val', 'test'
    splits_file='/../data/bench_splits.json',
    batch_size=8,
    num_workers=4,
    multigpu=False,
    shuffle=True,
    num_samples=None
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-3133de2d39ed> in <module>
#       9     multigpu=False,
#      10     shuffle=True,
# ---> 11     num_samples=None
#      12 )
#
# ~/3d-recon/src/dataloader.py in build_data_loader(data_dir, split_name, splits_file, batch_size, num_workers, multigpu, shuffle, num_samples)
#      35         return_id_str = True
#      36
# ---> 37     with PathManager.open(splits_file, "r") as f:
#      38         splits = json.load(f)
#      39     if split_name is not None:
#
# ~/3d-recon/env/lib/python3.7/site-packages/iopath/common/file_io.py in open(self, path, mode, buffering, **kwargs)
#     928         """
#     929         return self.__get_path_handler(path)._open(  # type: ignore
# --> 930             path, mode, buffering=buffering, **kwargs
#     931         )
#     932
#
# ~/3d-recon/env/lib/python3.7/site-packages/iopath/common/file_io.py in _open(self, path, mode, buffering, encoding, errors, newline, closefd, opener, **kwargs)
#     595             newline=newline,
#     596             closefd=closefd,
# --> 597             opener=opener,
#     598         )
#     599
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/data/bench_splits.json'

# %%
import torch
import os

SHAPENET_PATH = '/home/data/ShapeNet/ShapeNetV1processed/02691156/b2ceeee3c5b75962ac4f72bf08dc79a6'
metadata = os.path.join(SHAPENET_PATH, 'metadata.pt')
mesh = os.path.join(SHAPENET_PATH, 'mesh.pt')
samples = os.path.join(SHAPENET_PATH, 'samples.pt')

torch.load(metadata)
# Out:
# {'image_list': ['00.png',
#   '01.png',
#   '02.png',
#   '03.png',
#   '04.png',
#   '05.png',
#   '06.png',
#   '07.png',
#   '08.png',
#   '09.png',
#   '10.png',
#   '11.png',
#   '12.png',
#   '13.png',
#   '14.png',
#   '15.png',
#   '16.png',
#   '17.png',
#   '18.png',
#   '19.png',
#   '20.png',
#   '21.png',
#   '22.png',
#   '23.png'],
#  'intrinsic': tensor([[ 2.1875,  0.0000,  0.0000,  0.0000],
#          [ 0.0000,  2.1875,  0.0000,  0.0000],
#          [ 0.0000,  0.0000, -1.0020, -0.2002],
#          [ 0.0000,  0.0000, -1.0000,  0.0000]]),
#  'extrinsics': tensor([[[ 0.5900,  0.0000,  0.8074,  0.0000],
#           [ 0.3504,  0.9009, -0.2560,  0.0000],
#           [-0.7274,  0.4339,  0.5316, -1.5955],
#           [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#          [[ 0.9412,  0.0000,  0.3378,  0.0000],
#           [ 0.1480,  0.8989, -0.4124,  0.0000],
#           [-0.3036,  0.4381,  0.8461, -1.2371],
#           [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#          [[-0.2288,  0.0000,  0.9735,  0.0000],
#           [ 0.4645,  0.8788,  0.1092,  0.0000],
#           [-0.8555,  0.4772, -0.2011, -1.2603],
#           [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#          [[-0.9886,  0.0000, -0.1503,  0.0000],
#           [-0.0721,  0.8776,  0.4739,  0.0000],
#           [ 0.1319,  0.4794, -0.8676, -1.5424],
#           [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#          [[-0.1848,  0.0000,  0.9828,  0.0000],
#           [ 0.4289,  0.8998,  0.0807,  0.0000],
#           [-0.8843,  0.4364, -0.1663, -1.2465],
#           [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#          [[-0.5404,  0.0000,  0.8414,  0.0000],
#           [ 0.3621,  0.9026,  0.2326,  0.0000],
#           [-0.7595,  0.4304, -0.4878, -1.4237],
#           [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#          [[ 0.3781,  0.0000,  0.9258,  0.0000],
#           [ 0.4512,  0.8732, -0.1843,  0.0000],
#           [-0.8083,  0.4874,  0.3302, -1.1571],
#           [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#          [[ 0.8272,  0.0000,  0.5619,  0.0000],
#           [ 0.2641,  0.8827, -0.3888,  0.0000],
#           [-0.4960,  0.4700,  0.7301, -1.2500],
#           [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#          [[ 0.9240,  0.0000,  0.3823,  0.0000],
#           [ 0.1616,  0.9063, -0.3905,  0.0000],
#           [-0.3465,  0.4226,  0.8375, -1.5131],
#           [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#          [[-0.9593,  0.0000,  0.2824,  0.0000],
#           [ 0.1248,  0.8971,  0.4239,  0.0000],
#           [-0.2534,  0.4419, -0.8605, -1.2534],
#           [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#          [[ 0.9921,  0.0000, -0.1253,  0.0000],
#           [-0.0611,  0.8731, -0.4837,  0.0000],
#           [ 0.1094,  0.4875,  0.8662, -1.4632],
#           [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#          [[ 0.7107,  0.0000,  0.7035,  0.0000],
#           [ 0.3155,  0.8938, -0.3187,  0.0000],
#           [-0.6288,  0.4484,  0.6353, -1.2650],
#           [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#          [[ 0.5277,  0.0000,  0.8494,  0.0000],
#           [ 0.3796,  0.8946, -0.2358,  0.0000],
#           [-0.7599,  0.4469,  0.4721, -1.4695],
#           [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#          [[ 0.3910,  0.0000, -0.9204,  0.0000],
#           [-0.4596,  0.8664, -0.1952,  0.0000],
#           [ 0.7974,  0.4993,  0.3388, -1.6114],
#           [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#          [[ 0.9636,  0.0000,  0.2674,  0.0000],
#           [ 0.1167,  0.8997, -0.4207,  0.0000],
#           [-0.2406,  0.4366,  0.8669, -1.3430],
#           [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#          [[ 0.8585,  0.0000,  0.5128,  0.0000],
#           [ 0.2191,  0.9041, -0.3668,  0.0000],
#           [-0.4636,  0.4273,  0.7762, -1.2759],
#           [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#          [[-0.0562,  0.0000,  0.9984,  0.0000],
#           [ 0.4869,  0.8730,  0.0274,  0.0000],
#           [-0.8716,  0.4877, -0.0491, -1.4051],
#           [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#          [[-0.8189,  0.0000,  0.5739,  0.0000],
#           [ 0.2574,  0.8938,  0.3673,  0.0000],
#           [-0.5130,  0.4485, -0.7319, -1.4503],
#           [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#          [[-0.1637,  0.0000, -0.9865,  0.0000],
#           [-0.4893,  0.8683,  0.0812,  0.0000],
#           [ 0.8566,  0.4960, -0.1421, -1.4441],
#           [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#          [[ 0.3508,  0.0000, -0.9365,  0.0000],
#           [-0.4050,  0.9016, -0.1517,  0.0000],
#           [ 0.8443,  0.4325,  0.3163, -1.6349],
#           [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#          [[ 0.7954,  0.0000,  0.6061,  0.0000],
#           [ 0.2744,  0.8916, -0.3601,  0.0000],
#           [-0.5404,  0.4528,  0.7092, -1.4047],
#           [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#          [[-0.4362,  0.0000, -0.8999,  0.0000],
#           [-0.4176,  0.8858,  0.2024,  0.0000],
#           [ 0.7971,  0.4640, -0.3864, -1.5182],
#           [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#          [[-0.9504,  0.0000,  0.3112,  0.0000],
#           [ 0.1355,  0.9003,  0.4138,  0.0000],
#           [-0.2801,  0.4354, -0.8556, -1.5648],
#           [ 0.0000,  0.0000,  0.0000,  1.0000]],
#
#          [[ 0.1012,  0.0000, -0.9949,  0.0000],
#           [-0.4263,  0.9035, -0.0433,  0.0000],
#           [ 0.8989,  0.4285,  0.0914, -1.2837],
#           [ 0.0000,  0.0000,  0.0000,  1.0000]]])}

# %%
metadata_dict = torch.load(metadata)
metadata_dict['intrinsic'].shape
# Out:
# torch.Size([4, 4])

# %%
metadata_dict['extrinsics'].shape
# Out:
# torch.Size([24, 4, 4])

# %%
torch.load(mesh)
# Out:
# {'verts': tensor([[-0.3183,  0.0352, -0.0613],
#          [-0.2931, -0.0545, -0.0000],
#          [-0.3879,  0.0352, -0.0613],
#          [-0.2202, -0.0425, -0.0082],
#          [-0.1688, -0.0341, -0.0139],
#          [-0.2931, -0.0545, -0.0000],
#          [-0.3183,  0.0352,  0.0613],
#          [-0.3879,  0.0352,  0.0613],
#          [-0.2202, -0.0425,  0.0082],
#          [-0.1688, -0.0341,  0.0139],
#          [ 0.2798,  0.0054, -0.0000],
#          [ 0.2486,  0.0042,  0.0165],
#          [ 0.2388,  0.0319, -0.0000],
#          [ 0.2486,  0.0042, -0.0165],
#          [ 0.2039, -0.0545,  0.0828],
#          [ 0.1740, -0.0527,  0.0828],
#          [ 0.1740, -0.0545,  0.0828],
#          [ 0.2039, -0.0527,  0.0828],
#          [ 0.0382, -0.0527,  0.0828],
#          [-0.1275, -0.0545,  0.0828],
#          [ 0.1613, -0.0545,  0.1041],
#          [ 0.1613, -0.0527,  0.1041],
#          [ 0.3430, -0.0545,  0.0133],
#          [ 0.2039,  0.0009,  0.0414],
#          [ 0.0382, -0.0545,  0.0828],
#          [ 0.1740, -0.0088,  0.0828],
#          [-0.1993, -0.0545,  0.0469],
#          [ 0.3430, -0.0527,  0.0133],
#          [-0.1563, -0.0545,  0.0438],
#          [ 0.3524, -0.0527,  0.0086],
#          [-0.1275, -0.0527,  0.0828],
#          [-0.1993, -0.0527,  0.0469],
#          [-0.2519, -0.0527,  0.3107],
#          [ 0.3739, -0.0545,  0.0086],
#          [ 0.3524, -0.0545,  0.0086],
#          [ 0.0934, -0.0170,  0.0552],
#          [ 0.2449, -0.0009,  0.0223],
#          [-0.1102, -0.0527,  0.0841],
#          [-0.2202, -0.0545,  0.0048],
#          [-0.2907, -0.0527,  0.0012],
#          [-0.1102, -0.0545,  0.0841],
#          [-0.2519, -0.0545,  0.3107],
#          [-0.2775, -0.0527,  0.2912],
#          [ 0.3739, -0.0527,  0.0086],
#          [ 0.2867,  0.0009, -0.0000],
#          [ 0.1210,  0.0009,  0.0414],
#          [-0.2931, -0.0545, -0.0000],
#          [-0.2202, -0.0509,  0.0048],
#          [-0.1563, -0.0509,  0.0438],
#          [-0.1563, -0.0421,  0.0438],
#          [-0.2931, -0.0527, -0.0000],
#          [-0.2775, -0.0545,  0.2912],
#          [-0.2626, -0.0527,  0.3107],
#          [ 0.3610, -0.0545,  0.0043],
#          [ 0.2798,  0.0054, -0.0000],
#          [ 0.3281, -0.0327, -0.0000],
#          [ 0.1770,  0.0371,  0.0134],
#          [-0.2238, -0.0545,  0.0026],
#          [-0.2112, -0.0509,  0.0103],
#          [ 0.1488,  0.0426, -0.0000],
#          [-0.2112, -0.0394,  0.0103],
#          [-0.2626, -0.0545,  0.3107],
#          [ 0.3610, -0.0527,  0.0043],
#          [ 0.1815,  0.0142,  0.0228],
#          [ 0.2426,  0.0055,  0.0185],
#          [ 0.2449, -0.0009, -0.0223],
#          [ 0.3524, -0.0527, -0.0086],
#          [ 0.2039,  0.0545, -0.0000],
#          [ 0.1811,  0.0345,  0.0134],
#          [-0.2907, -0.0527, -0.0012],
#          [-0.2202, -0.0545, -0.0048],
#          [-0.2280, -0.0545, -0.0000],
#          [-0.2202, -0.0390,  0.0048],
#          [ 0.3879, -0.0545, -0.0000],
#          [ 0.3695, -0.0545, -0.0000],
#          [ 0.1488, -0.0545, -0.0000],
#          [ 0.2426,  0.0055, -0.0185],
#          [ 0.3610, -0.0527, -0.0043],
#          [ 0.3695, -0.0527, -0.0000],
#          [-0.1993, -0.0545, -0.0469],
#          [-0.1563, -0.0509, -0.0438],
#          [-0.2112, -0.0394, -0.0103],
#          [-0.2202, -0.0509, -0.0048],
#          [-0.1563, -0.0545, -0.0438],
#          [-0.2238, -0.0545, -0.0026],
#          [ 0.1770,  0.0371, -0.0134],
#          [ 0.3879, -0.0527, -0.0000],
#          [ 0.2149,  0.0313,  0.0062],
#          [ 0.1815,  0.0142, -0.0228],
#          [ 0.2039,  0.0009, -0.0414],
#          [ 0.3524, -0.0545, -0.0086],
#          [-0.1993, -0.0527, -0.0469],
#          [-0.2112, -0.0509, -0.0103],
#          [-0.2202, -0.0390, -0.0048],
#          [ 0.3430, -0.0545, -0.0133],
#          [ 0.3610, -0.0545, -0.0043],
#          [ 0.1811,  0.0345, -0.0134],
#          [-0.1275, -0.0527, -0.0828],
#          [ 0.2314,  0.0366, -0.0000],
#          [ 0.2149,  0.0313, -0.0062],
#          [ 0.1210,  0.0009, -0.0414],
#          [ 0.0934, -0.0170, -0.0552],
#          [ 0.3430, -0.0527, -0.0133],
#          [ 0.3739, -0.0545, -0.0086],
#          [-0.1563, -0.0421, -0.0438],
#          [ 0.2388,  0.0319, -0.0000],
#          [ 0.2039, -0.0527, -0.0828],
#          [ 0.3739, -0.0527, -0.0086],
#          [-0.1275, -0.0545, -0.0828],
#          [ 0.0382, -0.0527, -0.0828],
#          [ 0.2482,  0.0055,  0.0157],
#          [ 0.1740, -0.0088, -0.0828],
#          [ 0.1740, -0.0527, -0.0828],
#          [ 0.2039, -0.0545, -0.0828],
#          [ 0.0382, -0.0545, -0.0828],
#          [-0.1102, -0.0527, -0.0841],
#          [ 0.2482,  0.0055, -0.0157],
#          [ 0.1613, -0.0527, -0.1041],
#          [ 0.1740, -0.0545, -0.0828],
#          [ 0.1613, -0.0545, -0.1041],
#          [-0.1102, -0.0545, -0.0841],
#          [-0.2775, -0.0545, -0.2912],
#          [-0.2775, -0.0527, -0.2912],
#          [-0.2519, -0.0545, -0.3107],
#          [-0.2626, -0.0527, -0.3107],
#          [-0.2519, -0.0527, -0.3107],
#          [-0.2626, -0.0545, -0.3107]]),
#  'faces': tensor([[ 0,  1,  2],
#          [ 1,  0,  3],
#          [ 2,  1,  0],
#          ...,
#          [88, 99, 76],
#          [99, 88, 96],
#          [96, 88, 99]])}

# %%
torch.load(samples)
# Out:
# {'points_sampled': tensor([[-0.2471, -0.0268, -0.0190],
#          [-0.2369, -0.0545, -0.2473],
#          [ 0.1146, -0.0545, -0.0903],
#          ...,
#          [-0.0964, -0.0251,  0.0343],
#          [-0.0138,  0.0026, -0.0115],
#          [-0.2993, -0.0238, -0.0210]]),
#  'normals_sampled': tensor([[ 3.2330e-07,  5.6475e-01,  8.2526e-01],
#          [ 0.0000e+00,  1.0000e+00,  0.0000e+00],
#          [ 0.0000e+00, -1.0000e+00,  0.0000e+00],
#          ...,
#          [ 1.9417e-01, -9.0083e-01, -3.8834e-01],
#          [ 1.9417e-01, -9.0083e-01,  3.8833e-01],
#          [ 3.2330e-07,  5.6475e-01,  8.2526e-01]])}
